# %% [raw]
# Date - 02/11/2021  11:00 AM to 01:00 PM

# %% [markdown]
# ## Dependency Parsing
#
#     - Dependency parsing is analyzing the sentence in a grammatical way to establish dependency between "Head" words and
#       other words which modify those "Heads".
#
#     - The end result for dependency parsing can be thought to be creating a correct dependency tree as well as tagging
#       correct dependency tag on each word.
#
# ### Example:

# %%
import spacy
from spacy import displacy

# %%
nlp = spacy.load('en_core_web_sm')

# %%
sentence = nlp("The quick brown fox jumped over the lazy dog's back")

# %%
displacy.render(sentence, style='dep', jupyter=True, options={'distance':125})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="709735dcf29949d0934e4836a3cceac7-0" class="displacy" width="1425" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="175">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="175">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="300">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="425">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="675">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1050">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1175">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1175">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="1300">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1300">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-0" stroke-width="2px" d="M70,252.0 C70,64.5 420.0,64.5 420.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,254.0 L62,242.0 78,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-1" stroke-width="2px" d="M195,252.0 C195,127.0 415.0,127.0 415.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M195,254.0 L187,242.0 203,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-2" stroke-width="2px" d="M320,252.0 C320,189.5 410.0,189.5 410.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M320,254.0 L312,242.0 328,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-3" stroke-width="2px" d="M445,252.0 C445,189.5 535.0,189.5 535.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445,254.0 L437,242.0 453,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-4" stroke-width="2px" d="M570,252.0 C570,189.5 660.0,189.5 660.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M660.0,254.0 L668.0,242.0 652.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-5" stroke-width="2px" d="M820,252.0 C820,127.0 1040.0,127.0 1040.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M820,254.0 L812,242.0 828,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-6" stroke-width="2px" d="M945,252.0 C945,189.5 1035.0,189.5 1035.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M945,254.0 L937,242.0 953,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-7" stroke-width="2px" d="M1070,252.0 C1070,127.0 1290.0,127.0 1290.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-709735dcf29949d0934e4836a3cceac7-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1070,254.0 L1062,242.0 1078,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-709735dcf29949d0934e4836a3cceac7-0-8" stroke-width="2px" d="M1070,252.0 C1070,189.5 1160.0,189.5 1160.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow

# %%
dep_count = sentence.count_by(spacy.attrs.DEP)

# %%
dep_count
# Out:
# {415: 2,
#  402: 2,
#  7037928807040764755: 1,
#  429: 1,
#  8206900633647566924: 1,
#  443: 1,
#  440: 1,
#  8110129090154140942: 1,
#  439: 1}

# %%
for k,v in dep_count.items():
    print(f'{k},{sentence.vocab[k].text:{4}}:{v}')
# Out:
# 415,det :2
# 402,amod:2
# 7037928807040764755,compound:1
# 429,nsubj:1
# 8206900633647566924,ROOT:1
# 443,prep:1
# 440,poss:1
# 8110129090154140942,case:1
# 439,pobj:1

# %%
for token in sentence:
    print(f'{token.text:{10}} {token.pos_:{7}} {token.dep_:{10}} {spacy.explain(token.dep_)}')
# Out:
# The        DET     det        determiner
# quick      ADJ     amod       adjectival modifier
# brown      ADJ     compound   compound
# fox        NOUN    nsubj      nominal subject
# jumped     VERB    ROOT       None
# over       ADP     prep       prepositional modifier
# the        DET     det        determiner
# lazy       ADJ     amod       adjectival modifier
# dog        NOUN    poss       possession modifier
# 's         PART    case       case marking
# back       ADV     pobj       object of preposition

# %%
options={'distance':85, 'compact':True, 'color':'red', 'bg':'#09b3cd', 'font':'Times'}
displacy.render(sentence, style='dep', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="128d2b8436a7462ea0604d880a701842-0" class="displacy" width="985" height="307.0" direction="ltr" style="max-width: none; height: 307.0px; color: red; background: #09b3cd; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">The</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="135">quick</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="135">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="220">brown</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="220">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="305">fox</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="305">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="390">jumped</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="390">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="475">over</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="475">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="560">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="560">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="645">lazy</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="645">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="730">dog</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="730">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="815">'s</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="815">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="217.0">
#     <tspan class="displacy-word" fill="currentColor" x="900">back</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="900">ADV</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-0" stroke-width="2px" d="M62,172.0 62,129.5 302.0,129.5 302.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M62,174.0 L58,166.0 66,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-1" stroke-width="2px" d="M147,172.0 147,143.66666666666666 299.0,143.66666666666666 299.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M147,174.0 L143,166.0 151,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-2" stroke-width="2px" d="M232,172.0 232,157.83333333333334 296.0,157.83333333333334 296.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M232,174.0 L228,166.0 236,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-3" stroke-width="2px" d="M317,172.0 317,157.83333333333334 381.0,157.83333333333334 381.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M317,174.0 L313,166.0 321,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-4" stroke-width="2px" d="M402,172.0 402,157.83333333333334 466.0,157.83333333333334 466.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M466.0,174.0 L470.0,166.0 462.0,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-5" stroke-width="2px" d="M572,172.0 572,143.66666666666666 724.0,143.66666666666666 724.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M572,174.0 L568,166.0 576,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-6" stroke-width="2px" d="M657,172.0 657,157.83333333333334 721.0,157.83333333333334 721.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M657,174.0 L653,166.0 661,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-7" stroke-width="2px" d="M742,172.0 742,143.66666666666666 894.0,143.66666666666666 894.0,172.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-128d2b8436a7462ea0604d880a701842-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">poss</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M742,174.0 L738,166.0 746,166.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-128d2b8436a7462ea0604d880a701842-0-8" stroke-width="2px" d="M742,172.0 742,157.83333333333334 806.
