# %% [markdown]
# # File Handling In Python

# %% [markdown]
# Operations associated with the file handling :
# 1) Open
# 2) Read
# 3) Write
# 4) Edit (append)
# 5) Delete
#
# Steps :
# 1) Openning the file
# 2) Perform the operation
# 3) closing the file

# %% [markdown]
# ### Methods Associated With File Handling

# %% [markdown]
# "r" => read mode (default mode will be the read mode)
#
# "a" => append mode (if you want to add any new content without loosing the old content)
#
# "w" => write mode (if you want to add new data into a newly file created use the write mode, if you try to add any new content into the existing file then the old content would be lost)
#
# "r+" => open the file in both read & write mode
#
# "w+" => open a file for both writing & reading
#
# "a+" => open a file for both appending & reading

# %% [markdown]
# ## Reading Existing File

# %%
my_data = open("datasets/demo.txt", "r")  # read mode

# %%
print(my_data)
# Out:
# <_io.TextIOWrapper name='datasets/demo.txt' mode='r' encoding='cp1252'>

# %%
print(my_data.read())
# Out:
# i am a new content

# %%
my_data.read()
# Out:
# ''

# %%
my_data.close()

# %%
my_data.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABHIKU~1\AppData\Local\Temp/ipykernel_2616/541912962.py in <module>
# ----> 1 my_data.read()
#
# ValueError: I/O operation on closed file.

# %%
my_data = open("datasets/demo.txt", "r")
print(my_data.read(10))
my_data.close()
# Out:
# i am a new

# %%
my_data = open("datasets/demo.txt", "r")
print(my_data.readline())
print(my_data.readline())
my_data.close()
# Out:
# i am a new content

# %%
# using loops

my_data = open("datasets/demo.txt", "r")
for data in my_data:
    print(data)
my_data.close()
# Out:
# i am a new content

# %%
data
# Out:
# 'i am a new content'

# %%
# with keyword

with open("datasets/demo.txt","r") as my_data1:
    for data in my_data1:
        print(data)
# Out:
# i am a new content

# %%
my_data1.read()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\ABHIKU~1\AppData\Local\Temp/ipykernel_2616/4116059754.py in <module>
# ----> 1 my_data1.read()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ## Writing An Existing File

# %%
with open("datasets/demo.txt",'a') as my_cnt:
    my_cnt.write("\ni am a new content")

# %%
with open("datasets/demo.txt",'w') as my_cnt1:
    my_cnt1.write("i am a new content")

# %% [markdown]
# ## Writing A New File

# %%
with open("datasets/dummy.txt",'w') as my_cnt2:
    my_cnt2.write("i am a new content")

# %%
 with open("datasets/bio.txt",'a') as my_cnt2:
    my_cnt2.write("i am a new content")

# %% [markdown]
# ## Deleting A Line From File

# %%
cont = open('datasets/bio.txt','r')
lines = cont.readlines()
cont.close

lines.pop(1)

new_file = open('datasets/bio.txt','w')
for data in lines:
    new_file.write(data)
new_file.close()

# %% [markdown]
# ## Creating An Empty Text File

# %%
my_file = open("datasets/hello0.txt",'x')

# %%
my_file.close()

# %%
my_file = open("datasets/bio.txt",'x')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# C:\Users\ABHIKU~1\AppData\Local\Temp/ipykernel_2616/172006202.py in <module>
# ----> 1 my_file = open("datasets/bio.txt",'x')
#
# FileExistsError: [Errno 17] File exists: 'datasets/bio.txt'

# %% [markdown]
# ## Creating or Removing Existing File or Folder

# %%
import os

# %%
os.remove('datasets/hello0.txt')

# %%
os.mkdir("Pummy")

# %%
os.rmdir("Pummy")

# %%
os.mkdir("Nummy")

# %% [markdown]
# ## File Handling Questions

# %%
with open("datasets/odd_num.txt",'w') as odd:
    for num in range(1,101):
        if num%2 != 0:
            odd.write(str(num))
            odd.write('\n')

# %% [markdown]
# ### Copying the content from one file and storing it in another file

# %%
with open("datasets/cities.txt",'r') as f1:
    with open("datasets/new_cities.txt",'w') as f2:
        for data in f1:
            f2.write(data)

# %%
with open("datasets/cities.txt",'r') as f1:
    with open("datasets/demo_cities.txt",'w') as f2:
        for data in f1.readlines():
            if 'pune' in data:
                f2.write(data)

# %% [markdown]
# ## Binary Mode Reading & Writing Files

# %% [markdown]
# rb => reading binary files
#
# ab => appending binary files
#
# wb => writing binary files

# %%
with open("datasets/python.jpeg",'rb') as data:
    print(data.readlines())
# Out:
# [b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00\x84\x00\t\x06\x07\
x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x08\x089\xees\x1f\xf4\xd0\x0eH\x9c{\xdd\xfd\x17\xa1\xc2\xfae\xe7s~\xa8V\xb02\xcf\x95S\xe9\xdbCv\x8e\xf7\xd9\xbe\x1b{V\x9c\xbb\xe8\x9dz3\xe2\xd7\\o\xd5\xd9\xd7\x8c\xf6XX\xce\x87\xc9\xa7\xdd-\xa1\xb8\xc9\xa5~M\x12\xaf\x8f}q\xa52k\xa6v\xe2\x17^\xcb\xc6D\x94\x11%\x04ID\xa2T\x08\x92\x82$\xa0\xb6\xe6\xbe\xa0\xb6\xbc\xb7\x8aHd\x04s\xb4\xb5\xc3\xc0\xf7\xac\xdc\xb8\xde6\x9e,\xff\x00Q\xd6\xd7\x9a\xf4\x84\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x04\x1c\xeb9\x87\xfc\xc4=I\xf3\x95\xe8\xf0\xbe\x99\xfc\xbc\xeeg\xd5\x1f\x854\x95\xb1\x8dq\xc2r\xf9\xf1\xb02\xa23)h\xb0\x91\xae\rq\x1f\xbc\x08\xd6y\xd6,\x9cH\x99\xddgM\xb8\xf9s\x11\xabF\xda\xfc\xa5\xcb\tk\x19\xb91\xbb\x8c\'[\x85\xf4\x9e\xfbl\xd2<C\x99_\x0f\x1e1\xce\xe7\xc6\\\xf3r&\xf1\xa8\xf0\x85\\\x95\xa5\x9d\x12PD\x94J$\xa0\x89*\x07\x85\x04\tD\xad\x19\xb5\xf5\x94}T\xdeU\x9f\x95\xf6\xdd\xf8\xdfr\x1d\x89y\x8fL@@@@@@@@@@@@@@@@@@@@@A\xces\x9b\xc2!\xeaO\x9c\xafG\x85\xf4\xcf\xe5\xe7s>\xa8\xfc)\xa4\x1eC\xdc\xb62"A\xe4=\xca\x04KO!\xeeA\x12\x0f!\xeeA\x12\x0f!\xee(\x94\tA\x12\xa0D\x94\x11%\x12\x89(-\x19\xb4?\xf5(\xfa\xa9\xbc\xab?+\xed\xcb\xbf\x1b\xee;\x1a\xf3\x1e\x98\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x80\x83\xc7\x105\x9d@q\xa0\xd4\xd5\xe55\x14D\x87N\xc2G\x13/\'\x94\x15\xda\xb82[\xb48\xdb>:\xf7\x96\'\xcfZ\x0f\xf7\x1f\xf7R~\x8a\xdf\x0b\x97\xd1_\x8a\xc7\xea\xf3\xe7\xb5\x07\xfb\x8f\xfb\xa9?D\xf8\\\xbe\x87\xc5b\xf5D\xe5\xb6\x1f\xc6\xf7\xfd\xd3\xff\x00D\xf8\\\xbe\x88\xf8\xac^\xaf>{a\xde\xdb\xbe\xe5\xff\x00\xa2|._\xfaO\x8a\xc4|\xf6\xc3\xbd\xb7}\xcb\xff\x00D\xf8\\\xa7\xc5b\xf5\xfe\xcf>{\xe1\xde\xdb\xbe\xe5\xff\x00\xa2|.T\xfcV/W\x9f>0\xefm\xdfr\xff\x00\xd1>\x17)\xf18\xbf\xe8>|\xe1\xbe\xdb\xbe\xe6O\xd1>\x1b!\xf18\xdc\ ...

# %% [markdown]
# ## Copying Binary Files

# %%
with open("datasets/python.jpeg",'rb') as data:
    with open("datasets/copy.jpeg",'wb') as copied:
        for val in data:
            copied.write(val)

# %% [markdown]
# ## Seek Method

# %%
with open("datasets/hello.txt",'r') as data:
    data.seek(10)
    print(data.read())
    print(data.tell())
# Out:
# welcome
# bye
# 23

# %%
with open("datasets/seek.txt",'w+') as data:
    data.write('hello')
    data.write('\n')
    data.write('bye')
    data.seek(0)
    print(data.read())
# Out:
# hello
# bye
